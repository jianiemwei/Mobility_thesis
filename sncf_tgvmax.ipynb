# %% [markdown]
# # SNCF TGV Max - Zoom on the younger generation : 19-27 years old traveler

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)
import seaborn as sns

# %%
df=pd.read_csv('tgvmax.csv', sep=';')

# %%
df.head()
# Out:
#          DATE  TRAIN_NO     ENTITY   Axe Origine IATA Destination IATA  \
# 0  2020-11-26      4669  TJOURSOSE  TEOZ        FRXMW            FRXSY
# 1  2020-11-26      4669  TJOURSOSE  TEOZ        FRXMW            FRXYT
# 2  2020-11-26      4669  TJOURSOSE  TEOZ        FRXNA            FRMPL
# 3  2020-11-26      4752  TJOURSESO  TEOZ        FRBZR            FRBOJ
# 4  2020-11-26      4752  TJOURSESO  TEOZ        FRFNI            FRAGF
#
#                    Origine             Destination Heure_depart Heure_arrivee  \
# 0  MONTAUBAN VILLE BOURBON                    SETE        20:16         22:35
# 1  MONTAUBAN VILLE BOURBON       TOULOUSE MATABIAU        20:16         20:41
# 2                 NARBONNE  MONTPELLIER SAINT ROCH        22:01         22:53
# 3                  BEZIERS        BORDEAUX ST JEAN         7:45         11:30
# 4                    NIMES                    AGEN         6:37         10:21
#
#   Disponibilité de places TGV Max CODE_EQUIP
# ...

# %%
#df['DATE'] =  pd.to_datetime(df['DATE'])
#df.set_index(pd.DatetimeIndex(df['DATE']), drop=True)

# %%
df.rename(columns={'Disponibilité de places TGV Max': 'Dispo',},inplace=True)

# %%
df_new =df[['DATE','TRAIN_NO','Origine','Destination','Heure_depart', 'Heure_arrivee', 'Dispo']]
df_new.head()
df_new.to_csv('tgv.csv', sep='\t')

# %%
df_new['Destination'].value_counts()
# Out:
# PARIS (intramuros)                14017
# LYON (gares intramuros)            4240
# MARSEILLE ST CHARLES               3798
# BORDEAUX ST JEAN                   3204
# RENNES                             2670
# MONTPELLIER SAINT ROCH             2296
# NIMES                              2267
# VALENCE TGV RHONE ALPES SUD        2216
# NARBONNE                           2214
# AVIGNON TGV                        2145
# TOULOUSE MATABIAU                  2089
# BEZIERS                            2065
# STRASBOURG                         2040
# DIJON VILLE                        1906
# MULHOUSE VILLE                     1811
# BELFORT MONTBELIARD TGV            1749
# BESANCON Franche Comté TGV         1708
# AIX EN PROVENCE TGV                1659
# LE MANS                            1618
# CARCASSONNE                        1616
# TOULON                             1543
# MONTAUBAN VILLE BOURBON            1457
# NICE VILLE                         1452
# ...

# %%
df_new['Origine'].value_counts()
# Out:
# PARIS (intramuros)                14591
# LYON (gares intramuros)            4752
# MARSEILLE ST CHARLES               3712
# BORDEAUX ST JEAN                   3356
# RENNES                             2685
# NIMES                              2603
# MONTPELLIER SAINT ROCH             2574
# VALENCE TGV RHONE ALPES SUD        2345
# NARBONNE                           2223
# AVIGNON TGV                        2135
# BEZIERS                            2074
# TOULOUSE MATABIAU                  1986
# AIX EN PROVENCE TGV                1955
# STRASBOURG                         1886
# DIJON VILLE                        1765
# TOULON                             1758
# CARCASSONNE                        1591
# CANNES                             1580
# ANTIBES                            1571
# NICE VILLE                         1562
# MASSY TGV                          1559
# BELFORT MONTBELIARD TGV            1558
# MULHOUSE VILLE                     1556
# ...

# %%
df_new.isnull().sum()
# Out:
# DATE             0
# TRAIN_NO         0
# Origine          0
# Destination      0
# Heure_depart     0
# Heure_arrivee    0
# Dispo            0
# dtype: int64

# %%
df_new.tail()
# Out:
#               DATE  TRAIN_NO                  Origine         Destination  \
# 127571  2020-12-09      9560               STRASBOURG  PARIS (intramuros)
# 127572  2020-12-10      6612  LYON (gares intramuros)     MACON LOCHE TGV
# 127573  2020-12-10      6620  LYON (gares intramuros)  PARIS (intramuros)
# 127574  2020-12-10      6694  ST ETIENNE CHATEAUCREUX  PARIS (intramuros)
# 127575  2020-12-10      9560               STRASBOURG  PARIS (intramuros)
#
#        Heure_depart Heure_arrivee Dispo
# 127571        18:55         20:51   OUI
# 127572         9:51         10:28   OUI
# 127573        14:04         16:08   OUI
# 127574        11:55         15:01   OUI
# 127575        18:55         20:51   OUI

# %%
df_new['Dispo'].value_counts()
# Out:
# 1    67692
# 0    59884
# Name: Dispo, dtype: int64

# %%
59884/127576
# Out:
# 0.4693986329717188

# %%
df_new['Dispo'] = df_new['Dispo'].replace({'OUI':1, 'NON':0})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['Dispo'].value_counts()
# Out:
# 1    67692
# 0    59884
# Name: Dispo, dtype: int64

# %%
table = pd.pivot_table(df_new, values=['Dispo'], index=['Origine', 'Destination', 'DATE'],
                    aggfunc={'Dispo': np.sum})
table
# Out:
#                                                          Dispo
# Origine                  Destination         DATE
# AEROPORT CDG2 TGV ROISSY AGDE                2020-12-05      1
#                          AIX EN PROVENCE TGV 2020-12-02      1
#                                              2020-12-03      1
#                                              2020-12-04      1
#                                              2020-12-05      3
# ...                                                        ...
# VIVIEZ DECAZEVILLE       PARIS (intramuros)  2020-12-03      1
#                                              2020-12-04      1
#                                              2020-12-06      1
#                                              2020-12-07      1
#                                              2020-12-08      1
#
# [47868 rows x 1 columns]

# %%
flattened = pd.DataFrame(table.to_records())
flattened.to_csv('departure.csv', sep='\t')
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fe4794bb950> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
# ...
